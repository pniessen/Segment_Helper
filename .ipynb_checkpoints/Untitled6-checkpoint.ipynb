# %%
import numpy as np
import pandas as pd
infile = '/Users/pniessen/Rosetta_Desktop/Segmentation_2-point-0/segmentr/web/research_files/labelled_data/GP_Content_Seg_Input_File_092115_Full_Data.csv'

# %%
#X = np.genfromtxt(infile, delimiter=',', skip_header=2)
X = pd.DataFrame.from_csv(infile)
Y = pd.DataFrame.from_csv(infile)

# %%
X.ix[0,:]
# Out:
#                 q26_1          q26_2          q26_3          q26_4  \
# respid
# 10001    b_M2_Neutral   b_M3_Neutral  c_B2_Disagree   b_M2_Neutral
# 10002   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 10003   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 10004   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 10005    b_M2_Neutral   b_M3_Neutral   b_M2_Neutral  c_B2_Disagree
# 10006   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 10007    b_M2_Neutral   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 10008   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 10009    b_M2_Neutral   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 10010   c_B2_Disagree   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 10011   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 10012    b_M2_Neutral     a_T2_Agree   b_M2_Neutral   b_M2_Neutral
# 10013   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 10014    b_M2_Neutral     a_T2_Agree   b_M2_Neutral  c_B2_Disagree
# 10015    b_M2_Neutral   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 10016   c_B2_Disagree   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 10017    b_M2_Neutral     a_T2_Agree     a_T3_Agree     a_T3_Agree
# 10018      a_T3_Agree     a_T2_Agree   b_M2_Neutral   b_M2_Neutral
# 10019   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 10020   c_B2_Disagree     a_T2_Agree  c_B2_Disagree  c_B2_Disagree
# 10021   c_B2_Disagree   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 10022    b_M2_Neutral   b_M3_Neutral  c_B2_Disagree   b_M2_Neutral
# 10023   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 10024    b_M2_Neutral   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 10025   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 10026   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 10027   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 10028    b_M2_Neutral   b_M3_Neutral  c_B2_Disagree   b_M2_Neutral
# 10029   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 10030      a_T3_Agree     a_T2_Agree     a_T3_Agree     a_T3_Agree
# ...               ...            ...            ...            ...
# 11951   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 11952   c_B2_Disagree     a_T2_Agree  c_B2_Disagree  c_B2_Disagree
# 11953    b_M2_Neutral     a_T2_Agree   b_M2_Neutral   b_M2_Neutral
# 11954   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 11955    b_M2_Neutral   b_M3_Neutral  c_B2_Disagree   b_M2_Neutral
# 11956   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 11957   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 11958   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 11959      a_T3_Agree     a_T2_Agree     a_T3_Agree   b_M2_Neutral
# 11960   c_B2_Disagree   b_M3_Neutral   b_M2_Neutral  c_B2_Disagree
# 11961   c_B2_Disagree   b_M3_Neutral   b_M2_Neutral  c_B2_Disagree
# 11962    b_M2_Neutral     a_T2_Agree     a_T3_Agree   b_M2_Neutral
# 11963      a_T3_Agree   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 11964   c_B2_Disagree     a_T2_Agree  c_B2_Disagree  c_B2_Disagree
# 11965    b_M2_Neutral     a_T2_Agree   b_M2_Neutral  c_B2_Disagree
# 11966   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 11967   c_B2_Disagree   b_M3_Neutral   b_M2_Neutral     a_T3_Agree
# 11968   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 11969    b_M2_Neutral   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 11970   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 11971    b_M2_Neutral   b_M3_Neutral  c_B2_Disagree   b_M2_Neutral
# 11972   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 11973   c_B2_Disagree   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 11974    b_M2_Neutral  c_B2_Disagree   b_M2_Neutral  c_B2_Disagree
# 11975    b_M2_Neutral   b_M3_Neutral   b_M2_Neutral     a_T3_Agree
# 11976   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 11977    b_M2_Neutral   b_M3_Neutral   b_M2_Neutral   b_M2_Neutral
# 11978   c_B2_Disagree  c_B2_Disagree  c_B2_Disagree  c_B2_Disagree
# 11979   c_B2_Disagree   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
# 11980    b_M2_Neutral   b_M3_Neutral  c_B2_Disagree  c_B2_Disagree
#
#                 q26_5          q26_6          q26_7          q26_8  \
# respid
# 10001      a_T2_Agree   b_M2_Neutral   b_M2_Neutral   b_M2_Neutral
# 10002    b_M2_Neutral  c_B2_Disagree   b_M2_Neutral  c_B3_Disagree
# 10003      a_T2_Agree  c_B2_Disagree   b_M2_Neutral     a_T2_Agree
# 10004    b_M2_Neutral  c_B2_Disagree  c_B2_Disagree     a_T2_Agree
# 10005      a_T2_Agree   b_M2_Neutral   b_M2_Neutral     a_T2_Agree
# 10006      a_T2_Agree  c_B2_Disagree   b_M2_Neutral     a_T2_Agree
# 10007      a_T2_Agree  c_B2_Disagree   b_M2_Neutral     a_T2_Agree
# 10008      a_T2_Agree  c_B2_Disagree  c_B2_Disagree     a_T2_Agree
# 10009    b_M2_Neutral   b_M2_Neutral   b_M2_Neutral   b_M2_Neutral
# 10010      a_T2_Agree   b_M2_Neutral  c_B2_Disagree   b_M2_Neutral
# 10011    b_M2_Neutral  c_B2_Disagree  c_B2_Disagree   b_M2_Neutral
# 10012      a_T2_Agree     a_T3_Agree   b_M2_Neutral     a_T2_Agree
# 10013    b_M2_Neutral  c_B2_Disagree  c_B2_Disagree     a_T2_Agree
# 10014      a_T2_Agree   b_M2_Neutral     a_T3_Agree     a_T2_Agree
# 10015    b_M2_Neutral  c_B2_Disagree  c_B2_Disagree   b_M2_Neutral
# 10016    b_M2_Neutral   b_M2_Neutral   b_M2_Neutral   b_M2_Neutral
# 10017      a_T2_Agree     a_T3_Agree     a_T3_Agree     a_T2_Agree
# 10018      a_T2_Agree     a_T3_Agree     a_T3_Agree     a_T2_Agree
# 10019      a_T2_Agree  c_B2_Disagree   b_M2_Neutral     a_T2_Agree
# 10020      a_T2_Agree     a_T3_Agree     a_T3_Agree     a_T2_Agree
# 10021      a_T2_Agree   b_M2_Neutral   b_M2_Neutral     a_T2_Agree
# 10022   c_B3_Disagree  c_B2_Disagree     a_T3_Agree   b_M2_Neutral
# 10023    b_M2_Neutral  c_B2_Disagree  c_B2_Disagree   b_M2_Neutral
# 10024      a_T2_Agree   b_M2_Neutral   b_M2_Neutral     a_T2_Agree
# 10025   c_B3_Disagree  c_B2_Disagree  c_B2_Disagree  c_B3_Disagree
# 10026      a_T2_Agree  c_B2_Disagree  c_B2_Disagree   b_M2_Neutral
# 10027      a_T2_Agree   b_M2_Neutral  c_B2_Disagree     a_T2_Agree
# 10028      a_T2_Agree  c_B2_Disagree   b_M2_Neutral     a_T2_Agree
# 10029    b_M2_Neutral  c_B2_Disagree  c_B2_Disagree  c_B3_Disagree
# 10030      a_T2_Agree     a_T3_Agree     a_T3_Agree     a_T2_Agree
# ...               ...            ...            ...            ...
# 11951    b_M2_Neutral  c_B2_Disagree   b_M2_Neutral   b_M2_Neutral
# 11952    b_M2_Neutral     a_T3_Agree  c_B2_Disagree     a_T2_Agree
# 11953      a_T2_Agree     a_T3_Agree  c_B2_Disagree   b_M2_Neutral
# 11954    b_M2_Neutral   b_M2_Neutral  c_B2_Disagree  c_B3_Disagree
# 11955    b_M2_Neutral   b_M2_Neutral   b_M2_Neutral   b_M2_Neutral
# 11956   c_B3_Disagree  c_B2_Disagree  c_B2_Disagree  c_B3_Disagree
# 11957    b_M2_Neutral   b_M2_Neutral  c_B2_Disagree     a_T2_Agree
# 11958      a_T2_Agree   b_M2_Neutral  c_B2_Disagree   b_M2_Neutral
# 11959    b_M2_Neutral     a_T3_Agree     a_T3_Agree     a_T2_Agree
# 11960      a_T2_Agree   b_M2_Neutral   b_M2_Neutral     a_T2_Agree
# 11961      a_T2_Agree   b_M2_Neutral   b_M2_Neutral     a_T2_Agree
# 11962      a_T2_Agree   b_M2_Neutral   b_M2_Neutral     a_T2_Agree
# 11963    b_M2_Neutral   b_M2_Neutral  c_B2_Disagree   b_M2_Neutral
# 11964      a_T2_Agree  c_B2_Disagree  c_B2_Disagree     a_T2_Agree
# 11965      a_T2_Agree  c_B2_Disagree     a_T3_Agree   b_M2_Neutral
# 11966    b_M2_Neutral     a_T3_Agree     a_T3_Agree     a_T2_Agree
# 11967    b_M2_Neutral  c_B2_Disagree   b_M2_Neutral   b_M2_Neutral
# 11968    b_M2_Neutral  c_B2_Disagree   b_M2_Neutral     a_T2_Agree
# 11969      a_T2_Agree   b_M2_Neutral   b_M2_Neutral   b_M2_Neutral
# 11970      a_T2_Agree   b_M2_Neutral   b_M2_Neutral     a_T2_Agree
# 11971      a_T2_Agree   b_M2_Neutral  c_B2_Disagree     a_T2_Agree
# 11972      a_T2_Agree  c_B2_Disagree  c_B2_Disagree   b_M2_Neutral
# 11973      a_T2_Agree     a_T3_Agree   b_M2_Neutral     a_T2_Agree
# 11974    b_M2_Neutral  c_B2_Disagree   b_M2_Neutral   b_M2_Neutral
# 11975      a_T2_Agree   b_M2_Neutral     a_T3_Agree     a_T2_Agree
# 11976    b_M2_Neutral     a_T3_Agree  c_B2_Disagree     a_T2_Agree
# 11977    b_M2_Neutral   b_M2_Neutral  c_B2_Disagree   b_M2_Neutral
# 11978    b_M2_Neutral  c_B2_Disagree  c_B2_Disagree  c_B3_Disagree
# 11979      a_T2_Agree   b_M2_Neutral  c_B2_Disagree   b_M2_Neutral
# 11980      a_T2_Agree  c_B2_Disagree   b_M2_Neutral     a_T2_Agree
#
#                 q26_9         q26_10   ...    q25a_5  q25a_6  q25a_7  q25a_8  \
# respid                                 ...
# 10001      a_T2_Agree  c_B3_Disagree   ...         0       0       0       0
# 10002    b_M2_Neutral   b_M2_Neutral   ...    #NULL!  #NULL!  #NULL!  #NULL!
# 10003      a_T2_Agree  c_B3_Disagree   ...    #NULL!  #NULL!  #NULL!  #NULL!
# 10004      a_T2_Agree  c_B3_Disagree   ...         1       1  #NULL!       1
# 10005      a_T2_Agree   b_M2_Neutral   ...    #NULL!  #NULL!  #NULL!  #NULL!
# 10006      a_T2_Agree  c_B3_Disagree   ...         0       0       1       1
# 10007      a_T2_Agree  c_B3_Disagree   ...    #NULL!  #NULL!  #NULL!       0
# 10008    b_M2_Neutral  c_B3_Disagree   ...    #NULL!  #NULL!  #NULL!  #NULL!
# 10009    b_M2_Neutral  c_B3_Disagree   ...    #NULL!  #NULL!       0       0
# 10010    b_M2_Neutral  c_B3_Disagree   ...    #NULL!  #NULL!       0       0
# 10011      a_T2_Agree   b_M2_Neutral   ...    #NULL!  #NULL!  #NULL!  #NULL!
# 10012      a_T2_Agree     a_T2_Agree   ...         1       1       1       1
# 10013      a_T2_Agree     a_T2_Agree   ...    #NULL!       0  #NULL!       1
# 10014      a_T2_Agree     a_T2_Agree   ...    #NULL!  #NULL!  #NULL!  #NULL!
# 10015    b_M2_Neutral  c_B3_Disagree   ...         1  #NULL!       0       0
# 10016   c_B3_Disagree  c_B3_Disagree   ...         0  #NULL!  #NULL!       0
# 10017      a_T2_Agree     a_T2_Agree   ...         1  #NULL!       0       1
# 10018      a_T2_Agree     a_T2_Agree   ...         1  #NULL!  #NULL!       1
# 10019      a_T2_Agree     a_T2_Agree   ...    #NULL!  #NULL!       0       0
# 10020      a_T2_Agree     a_T2_Agree   ...    #NULL!       1       1       1
# 10021    b_M2_Neutral   b_M2_Neutral   ...    #NULL!  #NULL!  #NULL!  #NULL!
# 10022    b_M2_Neutral     a_T2_Agree   ...    #NULL!  #NULL!  #NULL!  #NULL!
# 10023    b_M2_Neutral  c_B3_Disagree   ...    #NULL!  #NULL!  #NULL!  #NULL!
# 10024      a_T2_Agree     a_T2_Agree   ...         0       0  #NULL!       1
# 10025   c_B3_Disagree  c_B3_Disagree   ...    #NULL!  #NULL!  #NULL!       1
# 10026    b_M2_Neutral  c_B3_Disagree   ...    #NULL!  #NULL!  #NULL!       1
# 10027      a_T2_Agree   b_M2_Neutral   ...         1  #NULL!  #NULL!       1
# 10028      a_T2_Agree   b_M2_Neutral   ...         0  #NULL!       1       1
# 10029   c_B3_Disagree  c_B3_Disagree   ...         1       0       0       0
# 10030      a_T2_Agree     a_T2_Agree   ...    #NULL!       0  #NULL!  #NULL!
# ...               ...            ...   ...       ...     ...     ...     ...
# 11951    b_M2_Neutral  c_B3_Disagree   ...    #NULL!  #NULL!  #NULL!       0
# 11952      a_T2_Agree     a_T2_Agree   ...    #NULL!  #NULL!  #NULL!       1
# 11953      a_T2_Agree     a_T2_Agree   ...         0       1       1       1
# 11954   c_B3_Disagree  c_B3_Disagree   ...         1       0  #NULL!       0
# 11955      a_T2_Agree   b_M2_Neutral   ...    #NULL!       0  #NULL!       1
# 11956   c_B3_Disagree  c_B3_Disagree   ...    #NULL!  #NULL!  #NULL!       0
# 11957      a_T2_Agree   b_M2_Neutral   ...         0  #NULL!  #NULL!       0
# 11958      a_T2_Agree   b_M2_Neutral   ...         0  #NULL!       0       0
# 11959    b_M2_Neutral     a_T2_Agree   ...         0       0       1       1
# 11960      a_T2_Agree     a_T2_Agree   ...         1       1       1       1
# 11961      a_T2_Agree   b_M2_Neutral   ...         1       0  #NULL!       0
# 11962      a_T2_Agree   b_M2_Neutral   ...         0       0       0       1
# 11963    b_M2_Neutral   b_M2_Neutral   ...         1       0       0       1
# 11964   c_B3_Disagree     a_T2_Agree   ...    #NULL!  #NULL!  #NULL!       1
# 11965      a_T2_Agree     a_T2_Agree   ...         1  #NULL!  #NULL!       1
# 11966      a_T2_Agree   b_M2_Neutral   ...         0       0       0       0
# 11967    b_M2_Neutral   b_M2_Neutral   ...         1       1       1       1
# 11968    b_M2_Neutral   b_M2_Neutral   ...         1       1       1       1
# 11969    b_M2_Neutral   b_M2_Neutral   ...         0  #NULL!  #NULL!       1
# 11970      a_T2_Agree   b_M2_Neutral   ...    #NULL!       1       1       1
# 11971      a_T2_Agree   b_M2_Neutral   ...    #NULL!       0       0       1
# 11972   c_B3_Disagree  c_B3_Disagree   ...         1  #NULL!  #NULL!       1
# 11973      a_T2_Agree   b_M2_Neutral   ...         0       0       1       1
# 11974    b_M2_Neutral   b_M2_Neutral   ...         0       0       0       0
# 11975      a_T2_Agree   b_M2_Neutral   ...    #NULL!       0       0       1
# 11976      a_T2_Agree     a_T2_Agree   ...    #NULL!  #NULL!  #NULL!       1
# 11977    b_M2_Neutral   b_M2_Neutral   ...         0       0       0       0
# 11978    b_M2_Neutral  c_B3_Disagree   ...         0  #NULL!       0       1
# 11979      a_T2_Agree   b_M2_Neutral   ...         1       1       0       1
# 11980      a_T2_Agree  c_B3_Disagree   ...         1       1       1       1
#
#         q25a_9 q25a_10 q25a_11 q25a_12    q27_1   q28_1
# respid
# 10001        0  #NULL!       0       0    b_1-9     a_0
# 10002   #NULL!  #NULL!  #NULL!  #NULL!    b_1-9   b_1-4
# 10003   #NULL!  #NULL!  #NULL!  #NULL!      a_0     a_0
# 10004        1  #NULL!       1  #NULL!    b_1-9   b_1-4
# 10005   #NULL!  #NULL!  #NULL!  #NULL!  c_10-24   b_1-4
# 10006        1       1       1       0  c_10-24   b_1-4
# 10007        1  #NULL!  #NULL!  #NULL!  e_50-99     a_0
# 10008   #NULL!  #NULL!  #NULL!  #NULL!    b_1-9     a_0
# 10009        0  #NULL!       1       1    b_1-9     a_0
# 10010        0       1       1  #NULL!    b_1-9   b_1-4
# 10011   #NULL!  #NULL!  #NULL!  #NULL!    b_1-9     a_0
# 10012        1       1       1       1    b_1-9     a_0
# 10013        0  #NULL!  #NULL!  #NULL!    b_1-9     a_0
# 10014   #NULL!  #NULL!  #NULL!  #NULL!  d_25-49   b_1-4
# 10015        0  #NULL!       0  #NULL!    b_1-9     a_0
# 10016        1  #NULL!  #NULL!  #NULL!    b_1-9     a_0
# 10017        0  #NULL!       0  #NULL!  d_25-49   b_1-4
# 10018        0  #NULL!  #NULL!       0  c_10-24     a_0
# 10019        1  #NULL!       1  #NULL!    b_1-9     a_0
# 10020        1  #NULL!       0  #NULL!  d_25-49   b_1-4
# 10021   #NULL!  #NULL!  #NULL!  #NULL!  d_25-49  c_5-14
# 10022   #NULL!  #NULL!  #NULL!  #NULL!      a_0     a_0
# 10023   #NULL!  #NULL!  #NULL!  #NULL!  c_10-24   b_1-4
# 10024        0  #NULL!       0       0    b_1-9   b_1-4
# 10025        0  #NULL!  #NULL!  #NULL!      a_0     a_0
# 10026        1  #NULL!       0  #NULL!  c_10-24   b_1-4
# 10027        0       0  #NULL!  #NULL!  c_10-24   b_1-4
# 10028        1       0       0  #NULL!    b_1-9     a_0
# 10029        0  #NULL!  #NULL!       1    b_1-9   b_1-4
# 10030        0  #NULL!       1  #NULL!  c_10-24     a_0
# ...        ...     ...     ...     ...      ...     ...
# 11951        1  #NULL!       0       0    b_1-9     a_0
# 11952        1  #NULL!       0       1    b_1-9   b_1-4
# 11953        0       1       1       0  c_10-24     a_0
# 11954        1  #NULL!       1       0    b_1-9     a_0
# 11955        0       0       1  #NULL!    b_1-9   b_1-4
# 11956        1       0  #NULL!       0      a_0     a_0
# 11957        1       0       1  #NULL!    b_1-9   b_1-4
# 11958        1       0       0       0    b_1-9     a_0
# 11959        1       1       0       1    b_1-9     a_0
# 11960        1       0       1       1  e_50-99     a_0
# 11961        1  #NULL!       0       0    b_1-9     a_0
# 11962        1       0       1       0  d_25-49   b_1-4
# 11963        1       1       1       0    b_1-9   b_1-4
# 11964        1       1       1       0  c_10-24   b_1-4
# 11965        0       0       1  #NULL!  c_10-24   b_1-4
# 11966        0       0       1  #NULL!  c_10-24   b_1-4
# 11967        1       0       1       1  c_10-24     a_0
# 11968        1       1       1       1  c_10-24     a_0
# 11969        0  #NULL!  #NULL!  #NULL!  d_25-49     a_0
# 11970        1  #NULL!       1       1  c_10-24   b_1-4
# 11971        0       0       1       0    b_1-9   b_1-4
# 11972        0  #NULL!  #NULL!  #NULL!  d_25-49   b_1-4
# 11973        1       0       1       0  c_10-24   b_1-4
# 11974        0       1       0       0      a_0     a_0
# 11975        0       0       0       0  c_10-24   b_1-4
# 11976        1  #NULL!       0       0    b_1-9   b_1-4
# 11977        1       0       0       0    b_1-9   b_1-4
# 11978        0       0       0  #NULL!    b_1-9     a_0
# 11979        1       1       1       1    b_1-9   b_1-4
# 11980        1       0       0       1  d_25-49   b_1-4
#
# [1980 rows x 357 columns]

# %%
X = X.ix[3:,6:]
Y = Y.ix[3:,6:]
question_names = X.columns
X = pd.DataFrame.as_matrix(X) #(row, col)

# %%
null_counter = 0
# for col in X.columns:
#     for index in X.index:
for col in range(X.shape[0]):
    for index in range(X.shape[1]):
        val = X[col][index]
        if val == '#NULL!' or val == ' ':
            val = 'n/a'
            null_counter += 1
        a = chr(146) # single quotation mark
        X[col][index] = val.replace("'","").replace("’","").replace(a,"").replace(" ","_")
        #val.decode('CP1252', 'ignore').encode('utf-8', 'ignore')

print null_counter
# Out:
# 65246

# %%
response_dict = {}
# for col in X.columns:
for index, question in enumerate(question_names):
    response_dict[question] = {}
    response_dict[question]['verbatim'] = sorted(list(set(X[:,index])))
    for item in response_dict[question]['verbatim']:
        response_dict[question][item] = response_dict[question]['verbatim'].index(item) + 1
        response_dict[question][response_dict[question][item]] = item

# %%
for col in range(X.shape[0]):
    for index in range(X.shape[1]):
        val = X[col][index]
        X[col][index] = response_dict[question_names[index]][val]

# %%
# Out:
# array([[3, 2, 3, ..., 3, 2, 2],
#        [3, 3, 3, ..., 3, 1, 1],
#        [3, 3, 3, ..., 3, 2, 2],
#        ...,
#        [3, 3, 3, ..., 3, 2, 1],
#        [3, 2, 3, ..., 2, 2, 2],
#        [2, 2, 3, ..., 2, 4, 2]], dtype=object)

# %%
Z = pd.DataFrame(X)
Z.columns = question_names

# %%
Z['q01_10'].describe()
# Out:
# count     1979
# unique       7
# top          7
# freq      1862
# Name: q01_10, dtype: int64

# %%
response_dict.items()
# Out:
# [('q47',
#   {1: 'a_I_exercise_rarely_and_would_not_consider_myself_to_be_physically_fit',
#    2: 'b_I_dont_exercise_very_often,_but_I_keep_myself_in_shape',
#    3: 'c_I_exercise_sometimes_and_maintain_a_good_level_of_fitness',
#    4: 'd_I_exercise_regularly_and_consider_myself_to_be_physically_fit',
#    'a_I_exercise_rarely_and_would_not_consider_myself_to_be_physically_fit': 1,
#    'b_I_dont_exercise_very_often,_but_I_keep_myself_in_shape': 2,
#    'c_I_exercise_sometimes_and_maintain_a_good_level_of_fitness': 3,
#    'd_I_exercise_regularly_and_consider_myself_to_be_physically_fit': 4,
#    'verbatim': ['a_I_exercise_rarely_and_would_not_consider_myself_to_be_physically_fit',
#     'b_I_dont_exercise_very_often,_but_I_keep_myself_in_shape',
#     'c_I_exercise_sometimes_and_maintain_a_good_level_of_fitness',
#     'd_I_exercise_regularly_and_consider_myself_to_be_physically_fit']}),
#  ('q22_2',
#   {1: 'a_1-99',
#    2: 'b_100-499',
#    3: 'c_500+',
#    4: 'no_account',
#    'a_1-99': 1,
#    'b_100-499': 2,
#    'c_500+': 3,
#    'no_account': 4,
#    'verbatim': ['a_1-99', 'b_100-499', 'c_500+', 'no_account']}),
#  ('q22_5',
#   {1: 'a_1-99',
#    2: 'b_100-499',
#    3: 'c_500+',
#    4: 'no_account',
#    'a_1-99': 1,
#    'b_100-499': 2,
#    'c_500+': 3,
#    'no_account': 4,
#    'verbatim': ['a_1-99', 'b_100-499', 'c_500+', 'no_account']}),
#  ('q22_4',
#   {1: 'a_1-99',
#    2: 'b_100-499',
#    3: 'c_500+',
#    4: 'no_account',
#    'a_1-99': 1,
#    'b_100-499': 2,
#    'c_500+': 3,
#    'no_account': 4,
#    'verbatim': ['a_1-99', 'b_100-499', 'c_500+', 'no_account']}),
#  ('q22_7',
#   {1: 'a_1-99',
#    2: 'b_100-499',
#    3: 'c_500+',
#    4: 'no_account',
#    'a_1-99': 1,
#    'b_100-499': 2,
#    'c_500+': 3,
#    'no_account': 4,
#    'verbatim': ['a_1-99', 'b_100-499', 'c_500+', 'no_account']}),
#  ('q22_9',
#   {1: 'a_1-99',
#    2: 'b_100-499',
#    3: 'c_500+',
#    4: 'no_account',
#    'a_1-99': 1,
#    'b_100-499': 2,
#    'c_500+': 3,
#    'no_account': 4,
#    'verbatim': ['a_1-99', 'b_100-499', 'c_500+', 'no_account']}),
#  ('q22_8',
#   {1: 'a_1-99',
#    2: 'b_100-499',
#    3: 'c_500+',
#    4: 'no_account',
#    'a_1-99': 1,
#    'b_100-499': 2,
#    'c_500+': 3,
#    'no_account': 4,
#    'verbatim': ['a_1-99', 'b_100-499', 'c_500+', 'no_account']}),
#  ('q29_6',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q29_7',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q29_4',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q29_5',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q29_2',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q29_3',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q29_1',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q29_8',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q29_9',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q41_27', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_26', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_25', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_24', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_23', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_22', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_21', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_20', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q49',
#   {1: 'a_Urban_/_city',
#    2: 'b_Suburban_/_outskirts_of_a_city',
#    3: 'c_Rural_/_countryside',
#    'a_Urban_/_city': 1,
#    'b_Suburban_/_outskirts_of_a_city': 2,
#    'c_Rural_/_countryside': 3,
#    'verbatim': ['a_Urban_/_city',
#     'b_Suburban_/_outskirts_of_a_city',
#     'c_Rural_/_countryside']}),
#  ('q41_28', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q29_10', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q01_10',
#   {1: 'a_0',
#    2: 'b_1-9',
#    3: 'c_10-24',
#    4: 'd_25-49',
#    5: 'e_50-99',
#    6: 'f_100+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-9': 2,
#    'c_10-24': 3,
#    'd_25-49': 4,
#    'e_50-99': 5,
#    'f_100+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-9',
#     'c_10-24',
#     'd_25-49',
#     'e_50-99',
#     'f_100+',
#     'n/a']}),
#  ('q31_3',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q08_1',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q08_3',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q08_2',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q08_5',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q08_4',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q08_7',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q08_6',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q08_8',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q31_4',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q03_6', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_7', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_4', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_5', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_2', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_3', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_1', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q31_6',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q03_8', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_9', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q07_8',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q07_9',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q07_2',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q07_3',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q07_1',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q07_6',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q07_7',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q07_4',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q07_5',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q40_5', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q40_4', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('Media_Flag', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q40_1', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q40_3', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q40_2', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q25a_12',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_10',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_11',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q32_18', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_19', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_10', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_11', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_12', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_13', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_14', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_15', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_16', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_17', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q01_3',
#   {1: 'a_0',
#    2: 'b_1-9',
#    3: 'c_10-24',
#    4: 'd_25-49',
#    5: 'e_50-99',
#    6: 'f_100+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-9': 2,
#    'c_10-24': 3,
#    'd_25-49': 4,
#    'e_50-99': 5,
#    'f_100+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-9',
#     'c_10-24',
#     'd_25-49',
#     'e_50-99',
#     'f_100+',
#     'n/a']}),
#  ('q01_4',
#   {1: 'a_0',
#    2: 'b_1-9',
#    3: 'c_10-24',
#    4: 'd_25-49',
#    5: 'e_50-99',
#    6: 'f_100+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-9': 2,
#    'c_10-24': 3,
#    'd_25-49': 4,
#    'e_50-99': 5,
#    'f_100+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-9',
#     'c_10-24',
#     'd_25-49',
#     'e_50-99',
#     'f_100+',
#     'n/a']}),
#  ('q01_5',
#   {1: 'a_0',
#    2: 'b_1-9',
#    3: 'c_10-24',
#    4: 'd_25-49',
#    5: 'e_50-99',
#    6: 'f_100+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-9': 2,
#    'c_10-24': 3,
#    'd_25-49': 4,
#    'e_50-99': 5,
#    'f_100+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-9',
#     'c_10-24',
#     'd_25-49',
#     'e_50-99',
#     'f_100+',
#     'n/a']}),
#  ('q01_6',
#   {1: 'a_0',
#    2: 'b_1-9',
#    3: 'c_10-24',
#    4: 'd_25-49',
#    5: 'e_50-99',
#    6: 'f_100+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-9': 2,
#    'c_10-24': 3,
#    'd_25-49': 4,
#    'e_50-99': 5,
#    'f_100+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-9',
#     'c_10-24',
#     'd_25-49',
#     'e_50-99',
#     'f_100+',
#     'n/a']}),
#  ('q01_7',
#   {1: 'a_0',
#    2: 'b_1-9',
#    3: 'c_10-24',
#    4: 'd_25-49',
#    5: 'e_50-99',
#    6: 'f_100+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-9': 2,
#    'c_10-24': 3,
#    'd_25-49': 4,
#    'e_50-99': 5,
#    'f_100+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-9',
#     'c_10-24',
#     'd_25-49',
#     'e_50-99',
#     'f_100+',
#     'n/a']}),
#  ('q01_8',
#   {1: 'a_0',
#    2: 'b_1-9',
#    3: 'c_10-24',
#    4: 'd_25-49',
#    5: 'e_50-99',
#    6: 'f_100+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-9': 2,
#    'c_10-24': 3,
#    'd_25-49': 4,
#    'e_50-99': 5,
#    'f_100+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-9',
#     'c_10-24',
#     'd_25-49',
#     'e_50-99',
#     'f_100+',
#     'n/a']}),
#  ('q01_9',
#   {1: 'a_0',
#    2: 'b_1-9',
#    3: 'c_10-24',
#    4: 'e_50-99',
#    5: 'n/a',
#    'a_0': 1,
#    'b_1-9': 2,
#    'c_10-24': 3,
#    'e_50-99': 4,
#    'n/a': 5,
#    'verbatim': ['a_0', 'b_1-9', 'c_10-24', 'e_50-99', 'n/a']}),
#  ('q21_8',
#   {1: 'a_0__or_\x91I_dont_have_an_account',
#    2: 'b_1-99',
#    3: 'c_100-499',
#    4: 'd_500+',
#    'a_0__or_\x91I_dont_have_an_account': 1,
#    'b_1-99': 2,
#    'c_100-499': 3,
#    'd_500+': 4,
#    'verbatim': ['a_0__or_\x91I_dont_have_an_account',
#     'b_1-99',
#     'c_100-499',
#     'd_500+']}),
#  ('q21_9',
#   {1: 'a_0__or_\x91I_dont_have_an_account',
#    2: 'b_1-99',
#    3: 'c_100-499',
#    4: 'd_500+',
#    'a_0__or_\x91I_dont_have_an_account': 1,
#    'b_1-99': 2,
#    'c_100-499': 3,
#    'd_500+': 4,
#    'verbatim': ['a_0__or_\x91I_dont_have_an_account',
#     'b_1-99',
#     'c_100-499',
#     'd_500+']}),
#  ('q21_6',
#   {1: 'a_0__or_\x91I_dont_have_an_account',
#    2: 'b_1-99',
#    3: 'c_100-499',
#    4: 'd_500+',
#    'a_0__or_\x91I_dont_have_an_account': 1,
#    'b_1-99': 2,
#    'c_100-499': 3,
#    'd_500+': 4,
#    'verbatim': ['a_0__or_\x91I_dont_have_an_account',
#     'b_1-99',
#     'c_100-499',
#     'd_500+']}),
#  ('q21_7',
#   {1: 'a_0__or_\x91I_dont_have_an_account',
#    2: 'b_1-99',
#    3: 'c_100-499',
#    4: 'd_500+',
#    'a_0__or_\x91I_dont_have_an_account': 1,
#    'b_1-99': 2,
#    'c_100-499': 3,
#    'd_500+': 4,
#    'verbatim': ['a_0__or_\x91I_dont_have_an_account',
#     'b_1-99',
#     'c_100-499',
#     'd_500+']}),
#  ('q21_4',
#   {1: 'a_0__or_\x91I_dont_have_an_account',
#    2: 'b_1-99',
#    3: 'c_100-499',
#    4: 'd_500+',
#    'a_0__or_\x91I_dont_have_an_account': 1,
#    'b_1-99': 2,
#    'c_100-499': 3,
#    'd_500+': 4,
#    'verbatim': ['a_0__or_\x91I_dont_have_an_account',
#     'b_1-99',
#     'c_100-499',
#     'd_500+']}),
#  ('q21_5',
#   {1: 'a_0__or_\x91I_dont_have_an_account',
#    2: 'b_1-99',
#    3: 'c_100-499',
#    4: 'd_500+',
#    'a_0__or_\x91I_dont_have_an_account': 1,
#    'b_1-99': 2,
#    'c_100-499': 3,
#    'd_500+': 4,
#    'verbatim': ['a_0__or_\x91I_dont_have_an_account',
#     'b_1-99',
#     'c_100-499',
#     'd_500+']}),
#  ('q21_2',
#   {1: 'a_0__or_\x91I_dont_have_an_account',
#    2: 'b_1-99',
#    3: 'c_100-499',
#    4: 'd_500+',
#    'a_0__or_\x91I_dont_have_an_account': 1,
#    'b_1-99': 2,
#    'c_100-499': 3,
#    'd_500+': 4,
#    'verbatim': ['a_0__or_\x91I_dont_have_an_account',
#     'b_1-99',
#     'c_100-499',
#     'd_500+']}),
#  ('q21_3',
#   {1: 'a_0__or_\x91I_dont_have_an_account',
#    2: 'b_1-99',
#    3: 'c_100-499',
#    4: 'd_500+',
#    'a_0__or_\x91I_dont_have_an_account': 1,
#    'b_1-99': 2,
#    'c_100-499': 3,
#    'd_500+': 4,
#    'verbatim': ['a_0__or_\x91I_dont_have_an_account',
#     'b_1-99',
#     'c_100-499',
#     'd_500+']}),
#  ('q21_1',
#   {1: 'a_0__or_\x91I_dont_have_an_account',
#    2: 'b_1-99',
#    3: 'c_100-499',
#    4: 'd_500+',
#    'a_0__or_\x91I_dont_have_an_account': 1,
#    'b_1-99': 2,
#    'c_100-499': 3,
#    'd_500+': 4,
#    'verbatim': ['a_0__or_\x91I_dont_have_an_account',
#     'b_1-99',
#     'c_100-499',
#     'd_500+']}),
#  ('q27_1',
#   {1: 'a_0',
#    2: 'b_1-9',
#    3: 'c_10-24',
#    4: 'd_25-49',
#    5: 'e_50-99',
#    6: 'f_100+',
#    'a_0': 1,
#    'b_1-9': 2,
#    'c_10-24': 3,
#    'd_25-49': 4,
#    'e_50-99': 5,
#    'f_100+': 6,
#    'verbatim': ['a_0', 'b_1-9', 'c_10-24', 'd_25-49', 'e_50-99', 'f_100+']}),
#  ('q31_7',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q32_20', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q48_9',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q48_8',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q48_5',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_4',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_7',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q48_6',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q48_1',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_3',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_2',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_35',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_34',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_33',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_32',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q41_18', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_19', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_16', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_17', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_14', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_15', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_12', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_13', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_10', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_11', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q51',
#   {1: 'Prefer_not_to_answer',
#    2: 'a_I_live_alone',
#    3: 'b_I_live_alone_with_my_children',
#    4: 'c_I_live_with_my_spouse_/_partner',
#    5: 'd_I_live_with_my_spouse_/_partner_and_my_children',
#    6: 'e_I_live_with_my_parent(s)',
#    7: 'f_I_live_with_my_extended_family_which_includes_my_spouse_/_children_and_/_or_parents,_grandparents,_other_relatives',
#    8: 'g_I_live_with_my_roommate(s)',
#    9: 'z_Other',
#    'Prefer_not_to_answer': 1,
#    'a_I_live_alone': 2,
#    'b_I_live_alone_with_my_children': 3,
#    'c_I_live_with_my_spouse_/_partner': 4,
#    'd_I_live_with_my_spouse_/_partner_and_my_children': 5,
#    'e_I_live_with_my_parent(s)': 6,
#    'f_I_live_with_my_extended_family_which_includes_my_spouse_/_children_and_/_or_parents,_grandparents,_other_relatives': 7,
#    'g_I_live_with_my_roommate(s)': 8,
#    'verbatim': ['Prefer_not_to_answer',
#     'a_I_live_alone',
#     'b_I_live_alone_with_my_children',
#     'c_I_live_with_my_spouse_/_partner',
#     'd_I_live_with_my_spouse_/_partner_and_my_children',
#     'e_I_live_with_my_parent(s)',
#     'f_I_live_with_my_extended_family_which_includes_my_spouse_/_children_and_/_or_parents,_grandparents,_other_relatives',
#     'g_I_live_with_my_roommate(s)',
#     'z_Other'],
#    'z_Other': 9}),
#  ('q50',
#   {1: 'a_Employed_full-time_by_someone_else,_working_30_hours_or_more_per_week',
#    2: 'b_Employed_part-time_by_someone_else,_working_less_than_30_hours_per_week',
#    3: 'c_Self-employed_(either_full-time_or_part-time)',
#    4: 'd_Student',
#    5: 'e_Homemaker',
#    6: 'f_Unemployed',
#    7: 'g_Retired',
#    8: 'z_Other',
#    'a_Employed_full-time_by_someone_else,_working_30_hours_or_more_per_week': 1,
#    'b_Employed_part-time_by_someone_else,_working_less_than_30_hours_per_week': 2,
#    'c_Self-employed_(either_full-time_or_part-time)': 3,
#    'd_Student': 4,
#    'e_Homemaker': 5,
#    'f_Unemployed': 6,
#    'g_Retired': 7,
#    'verbatim': ['a_Employed_full-time_by_someone_else,_working_30_hours_or_more_per_week',
#     'b_Employed_part-time_by_someone_else,_working_less_than_30_hours_per_week',
#     'c_Self-employed_(either_full-time_or_part-time)',
#     'd_Student',
#     'e_Homemaker',
#     'f_Unemployed',
#     'g_Retired',
#     'z_Other'],
#    'z_Other': 8}),
#  ('q53',
#   {1: 'a_Some_high_school_or_less',
#    2: 'b_Completed_high_school',
#    3: 'c_Some_college_/_Associate_Degree',
#    4: 'd_Completed_technical_or_vocational_school',
#    5: 'e_Completed_college',
#    6: 'f_Graduate_school',
#    'a_Some_high_school_or_less': 1,
#    'b_Completed_high_school': 2,
#    'c_Some_college_/_Associate_Degree': 3,
#    'd_Completed_technical_or_vocational_school': 4,
#    'e_Completed_college': 5,
#    'f_Graduate_school': 6,
#    'verbatim': ['a_Some_high_school_or_less',
#     'b_Completed_high_school',
#     'c_Some_college_/_Associate_Degree',
#     'd_Completed_technical_or_vocational_school',
#     'e_Completed_college',
#     'f_Graduate_school']}),
#  ('q55',
#   {1: 'a_White_/_Caucasian',
#    2: 'b_Black_/_African_American',
#    3: 'c_Hispanic',
#    4: 'd_Asian_/_Pacific_Islander',
#    5: 'e_Native_American_/_American_Indian',
#    6: 'f_Multi-racial',
#    7: 'y_Other',
#    8: 'z_Prefer_not_to_answer',
#    'a_White_/_Caucasian': 1,
#    'b_Black_/_African_American': 2,
#    'c_Hispanic': 3,
#    'd_Asian_/_Pacific_Islander': 4,
#    'e_Native_American_/_American_Indian': 5,
#    'f_Multi-racial': 6,
#    'verbatim': ['a_White_/_Caucasian',
#     'b_Black_/_African_American',
#     'c_Hispanic',
#     'd_Asian_/_Pacific_Islander',
#     'e_Native_American_/_American_Indian',
#     'f_Multi-racial',
#     'y_Other',
#     'z_Prefer_not_to_answer'],
#    'y_Other': 7,
#    'z_Prefer_not_to_answer': 8}),
#  ('q54',
#   {1: 'a_Less_than_$25,000',
#    2: 'b_$25,000_to_$34,999',
#    3: 'c_$35,000_to_$44,999',
#    4: 'd_$45,000_to_$54,999',
#    5: 'e_$55,000_to_$64,999',
#    6: 'f_$65,000_to_$74,999',
#    7: 'g_$75,000_to_$99,999',
#    8: 'h_$100,000_to_$249,999',
#    9: 'i_$250,000_or_more',
#    10: 'y_Prefer_not_to_answer',
#    'a_Less_than_$25,000': 1,
#    'b_$25,000_to_$34,999': 2,
#    'c_$35,000_to_$44,999': 3,
#    'd_$45,000_to_$54,999': 4,
#    'e_$55,000_to_$64,999': 5,
#    'f_$65,000_to_$74,999': 6,
#    'g_$75,000_to_$99,999': 7,
#    'h_$100,000_to_$249,999': 8,
#    'i_$250,000_or_more': 9,
#    'verbatim': ['a_Less_than_$25,000',
#     'b_$25,000_to_$34,999',
#     'c_$35,000_to_$44,999',
#     'd_$45,000_to_$54,999',
#     'e_$55,000_to_$64,999',
#     'f_$65,000_to_$74,999',
#     'g_$75,000_to_$99,999',
#     'h_$100,000_to_$249,999',
#     'i_$250,000_or_more',
#     'y_Prefer_not_to_answer'],
#    'y_Prefer_not_to_answer': 10}),
#  ('q31_20',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q28_1',
#   {1: 'a_0',
#    2: 'b_1-4',
#    3: 'c_5-14',
#    4: 'd_15-24',
#    5: 'e_25-49',
#    6: 'f_50+',
#    'a_0': 1,
#    'b_1-4': 2,
#    'c_5-14': 3,
#    'd_15-24': 4,
#    'e_25-49': 5,
#    'f_50+': 6,
#    'verbatim': ['a_0', 'b_1-4', 'c_5-14', 'd_15-24', 'e_25-49', 'f_50+']}),
#  ('s07x1_7', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('s07x1_6', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('s07x1_5', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('s07x1_4', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('s07x1_3', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('s07x1_2', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('s07x1_1', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q48_30',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('s07x1_9', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('s07x1_8', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('Device Segments',
#   {1: '1_Expressive_Adventurers',
#    2: '2_Dedicated_Capturers',
#    3: '3_Instant_Sharers',
#    4: '4_Connected_Followers',
#    5: '5_The_Traditionalists',
#    6: '6_The_Minimalists',
#    '1_Expressive_Adventurers': 1,
#    '2_Dedicated_Capturers': 2,
#    '3_Instant_Sharers': 3,
#    '4_Connected_Followers': 4,
#    '5_The_Traditionalists': 5,
#    '6_The_Minimalists': 6,
#    'verbatim': ['1_Expressive_Adventurers',
#     '2_Dedicated_Capturers',
#     '3_Instant_Sharers',
#     '4_Connected_Followers',
#     '5_The_Traditionalists',
#     '6_The_Minimalists']}),
#  ('q02_9',
#   {1: 'a_0',
#    2: 'b_1-4',
#    3: 'c_5-14',
#    4: 'd_15-24',
#    5: 'f_50+',
#    6: 'n/a',
#    'a_0': 1,
#    'b_1-4': 2,
#    'c_5-14': 3,
#    'd_15-24': 4,
#    'f_50+': 5,
#    'n/a': 6,
#    'verbatim': ['a_0', 'b_1-4', 'c_5-14', 'd_15-24', 'f_50+', 'n/a']}),
#  ('q02_8',
#   {1: 'a_0',
#    2: 'b_1-4',
#    3: 'c_5-14',
#    4: 'd_15-24',
#    5: 'e_25-49',
#    6: 'f_50+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-4': 2,
#    'c_5-14': 3,
#    'd_15-24': 4,
#    'e_25-49': 5,
#    'f_50+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-4',
#     'c_5-14',
#     'd_15-24',
#     'e_25-49',
#     'f_50+',
#     'n/a']}),
#  ('q02_7',
#   {1: 'a_0',
#    2: 'b_1-4',
#    3: 'c_5-14',
#    4: 'd_15-24',
#    5: 'e_25-49',
#    6: 'f_50+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-4': 2,
#    'c_5-14': 3,
#    'd_15-24': 4,
#    'e_25-49': 5,
#    'f_50+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-4',
#     'c_5-14',
#     'd_15-24',
#     'e_25-49',
#     'f_50+',
#     'n/a']}),
#  ('q02_6',
#   {1: 'a_0',
#    2: 'b_1-4',
#    3: 'c_5-14',
#    4: 'd_15-24',
#    5: 'e_25-49',
#    6: 'f_50+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-4': 2,
#    'c_5-14': 3,
#    'd_15-24': 4,
#    'e_25-49': 5,
#    'f_50+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-4',
#     'c_5-14',
#     'd_15-24',
#     'e_25-49',
#     'f_50+',
#     'n/a']}),
#  ('q02_5',
#   {1: 'a_0',
#    2: 'b_1-4',
#    3: 'c_5-14',
#    4: 'd_15-24',
#    5: 'f_50+',
#    6: 'n/a',
#    'a_0': 1,
#    'b_1-4': 2,
#    'c_5-14': 3,
#    'd_15-24': 4,
#    'f_50+': 5,
#    'n/a': 6,
#    'verbatim': ['a_0', 'b_1-4', 'c_5-14', 'd_15-24', 'f_50+', 'n/a']}),
#  ('q02_4',
#   {1: 'a_0',
#    2: 'b_1-4',
#    3: 'c_5-14',
#    4: 'd_15-24',
#    5: 'e_25-49',
#    6: 'f_50+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-4': 2,
#    'c_5-14': 3,
#    'd_15-24': 4,
#    'e_25-49': 5,
#    'f_50+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-4',
#     'c_5-14',
#     'd_15-24',
#     'e_25-49',
#     'f_50+',
#     'n/a']}),
#  ('q02_3',
#   {1: 'a_0',
#    2: 'b_1-4',
#    3: 'c_5-14',
#    4: 'd_15-24',
#    5: 'e_25-49',
#    6: 'f_50+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-4': 2,
#    'c_5-14': 3,
#    'd_15-24': 4,
#    'e_25-49': 5,
#    'f_50+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-4',
#     'c_5-14',
#     'd_15-24',
#     'e_25-49',
#     'f_50+',
#     'n/a']}),
#  ('q06_3',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q06_2',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q06_1',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q06_7',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q06_6',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q06_5',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q06_4',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q06_9',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q06_8',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q41_8', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_9', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q48_31',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q41_4', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_5', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_6', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_7', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_1', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_2', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q41_3', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q24a_11',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q24a_10',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q16_1',
#   {1: '0',
#    2: 'a_T3_Agree',
#    3: 'b_M2_Neutral',
#    4: 'c_B2_Disagree',
#    '0': 1,
#    'a_T3_Agree': 2,
#    'b_M2_Neutral': 3,
#    'c_B2_Disagree': 4,
#    'verbatim': ['0', 'a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q37_1', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q16_4',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q16_5',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q16_6',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q16_7',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q37_10', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q06_13',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q06_12',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q06_11',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q06_10',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q06_17',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q06_16',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q06_15',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q06_14',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q05',
#   {1: 'a_Share_with_friends_and_family_live_and/or_via_email',
#    2: 'b_Share_online_via_social_media_(e.g.,_posting_them_on_Facebook)',
#    3: 'c_View_for_myself',
#    'a_Share_with_friends_and_family_live_and/or_via_email': 1,
#    'b_Share_online_via_social_media_(e.g.,_posting_them_on_Facebook)': 2,
#    'c_View_for_myself': 3,
#    'verbatim': ['a_Share_with_friends_and_family_live_and/or_via_email',
#     'b_Share_online_via_social_media_(e.g.,_posting_them_on_Facebook)',
#     'c_View_for_myself']}),
#  ('q31_2',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q32_8', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_9', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_6', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_7', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_4', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_5', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_2', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_3', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q32_1', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q34_1',
#   {1: 'a_0',
#    2: 'b_1-4_Hours',
#    3: 'c_5-9_Hours',
#    4: 'd_10+_Hours',
#    'a_0': 1,
#    'b_1-4_Hours': 2,
#    'c_5-9_Hours': 3,
#    'd_10+_Hours': 4,
#    'verbatim': ['a_0', 'b_1-4_Hours', 'c_5-9_Hours', 'd_10+_Hours']}),
#  ('q34_2',
#   {1: 'a_0',
#    2: 'b_1-4_Hours',
#    3: 'c_5-9_Hours',
#    4: 'd_10+_Hours',
#    'a_0': 1,
#    'b_1-4_Hours': 2,
#    'c_5-9_Hours': 3,
#    'd_10+_Hours': 4,
#    'verbatim': ['a_0', 'b_1-4_Hours', 'c_5-9_Hours', 'd_10+_Hours']}),
#  ('New_GoPro_Flag', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q31_5',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q02_10',
#   {1: 'a_0',
#    2: 'b_1-4',
#    3: 'c_5-14',
#    4: 'd_15-24',
#    5: 'e_25-49',
#    6: 'f_50+',
#    7: 'n/a',
#    'a_0': 1,
#    'b_1-4': 2,
#    'c_5-14': 3,
#    'd_15-24': 4,
#    'e_25-49': 5,
#    'f_50+': 6,
#    'n/a': 7,
#    'verbatim': ['a_0',
#     'b_1-4',
#     'c_5-14',
#     'd_15-24',
#     'e_25-49',
#     'f_50+',
#     'n/a']}),
#  ('q46',
#   {1: 'a_I_do_not_own_or_use_any_wearable_technology',
#    2: 'b_I_own_some_wearable_technology,_but_I_rarely_use_it',
#    3: 'c_I_own_some_wearable_technology,_and_I_use_it_sometimes',
#    4: 'd_I_own_some_wearable_technology,_and_I_use_it_almost_all_the_time_(i.e.,_every_day)',
#    'a_I_do_not_own_or_use_any_wearable_technology': 1,
#    'b_I_own_some_wearable_technology,_but_I_rarely_use_it': 2,
#    'c_I_own_some_wearable_technology,_and_I_use_it_sometimes': 3,
#    'd_I_own_some_wearable_technology,_and_I_use_it_almost_all_the_time_(i.e.,_every_day)': 4,
#    'verbatim': ['a_I_do_not_own_or_use_any_wearable_technology',
#     'b_I_own_some_wearable_technology,_but_I_rarely_use_it',
#     'c_I_own_some_wearable_technology,_and_I_use_it_sometimes',
#     'd_I_own_some_wearable_technology,_and_I_use_it_almost_all_the_time_(i.e.,_every_day)']}),
#  ('q39_8',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q45',
#   {1: 'a_I_have_not_traveled_in_the_past_12_months',
#    2: 'b_I_have_done_some_traveling_in_the_past_12_months,_but_it_was_mostly_for_work',
#    3: 'c_I_have_done_some_traveling_in_the_past_12_months,_and_it_was_mostly_for_vacation/pleasure',
#    4: 'd_I_have_done_a_lot_of_traveling_in_the_past_12_months_for_vacation/pleasure',
#    'a_I_have_not_traveled_in_the_past_12_months': 1,
#    'b_I_have_done_some_traveling_in_the_past_12_months,_but_it_was_mostly_for_work': 2,
#    'c_I_have_done_some_traveling_in_the_past_12_months,_and_it_was_mostly_for_vacation/pleasure': 3,
#    'd_I_have_done_a_lot_of_traveling_in_the_past_12_months_for_vacation/pleasure': 4,
#    'verbatim': ['a_I_have_not_traveled_in_the_past_12_months',
#     'b_I_have_done_some_traveling_in_the_past_12_months,_but_it_was_mostly_for_work',
#     'c_I_have_done_some_traveling_in_the_past_12_months,_and_it_was_mostly_for_vacation/pleasure',
#     'd_I_have_done_a_lot_of_traveling_in_the_past_12_months_for_vacation/pleasure']}),
#  ('q42',
#   {1: 'a_I_have_never_had_any_free_time_for_hobbies_and_activities',
#    2: 'b_I_used_to_have_more_free_time_for_hobbies_and_activities_than_I_do_now',
#    3: 'c_I_have_some_free_time_for_hobbies_and_activities',
#    4: 'd_I_have_plenty_of_free_time_for_hobbies_and_activities',
#    'a_I_have_never_had_any_free_time_for_hobbies_and_activities': 1,
#    'b_I_used_to_have_more_free_time_for_hobbies_and_activities_than_I_do_now': 2,
#    'c_I_have_some_free_time_for_hobbies_and_activities': 3,
#    'd_I_have_plenty_of_free_time_for_hobbies_and_activities': 4,
#    'verbatim': ['a_I_have_never_had_any_free_time_for_hobbies_and_activities',
#     'b_I_used_to_have_more_free_time_for_hobbies_and_activities_than_I_do_now',
#     'c_I_have_some_free_time_for_hobbies_and_activities',
#     'd_I_have_plenty_of_free_time_for_hobbies_and_activities']}),
#  ('q39_1',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q39_3',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q39_2',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q39_5',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q39_4',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q39_7',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q39_6',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q34_2_Bucketed',
#   {1: 'a_0',
#    2: 'b_1-4_Hours',
#    3: 'c_5-9_Hours',
#    4: 'd_10+_Hours',
#    'a_0': 1,
#    'b_1-4_Hours': 2,
#    'c_5-9_Hours': 3,
#    'd_10+_Hours': 4,
#    'verbatim': ['a_0', 'b_1-4_Hours', 'c_5-9_Hours', 'd_10+_Hours']}),
#  ('q36',
#   {1: 'a_<_30_minutes',
#    2: 'b_30_minutes-1_hour',
#    3: 'c_1+_hours',
#    4: 'z_None',
#    'a_<_30_minutes': 1,
#    'b_30_minutes-1_hour': 2,
#    'c_1+_hours': 3,
#    'verbatim': ['a_<_30_minutes',
#     'b_30_minutes-1_hour',
#     'c_1+_hours',
#     'z_None'],
#    'z_None': 4}),
#  ('q16_8',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q16_9',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q37_9', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q37_8', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q37_3', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q37_2', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q16_2',
#   {1: '0',
#    2: 'a_T3_Agree',
#    3: 'b_M2_Neutral',
#    4: 'c_B2_Disagree',
#    '0': 1,
#    'a_T3_Agree': 2,
#    'b_M2_Neutral': 3,
#    'c_B2_Disagree': 4,
#    'verbatim': ['0', 'a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q16_3',
#   {1: '0',
#    2: 'a_T2_Agree',
#    3: 'b_M2_Neutral',
#    4: 'c_B3_Disagree',
#    '0': 1,
#    'a_T2_Agree': 2,
#    'b_M2_Neutral': 3,
#    'c_B3_Disagree': 4,
#    'verbatim': ['0', 'a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q37_7', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q37_6', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q37_5', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q37_4', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q25a_4',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_5',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_6',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_7',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_1',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_2',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_3',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_8',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q25a_9',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q33_5',
#   {1: 'a_0',
#    2: 'b_1-4_Hours',
#    3: 'c_5+_Hours',
#    'a_0': 1,
#    'b_1-4_Hours': 2,
#    'c_5+_Hours': 3,
#    'verbatim': ['a_0', 'b_1-4_Hours', 'c_5+_Hours']}),
#  ('q33_4',
#   {1: 'a_0',
#    2: 'b_1-4_Hours',
#    3: 'c_5+_Hours',
#    'a_0': 1,
#    'b_1-4_Hours': 2,
#    'c_5+_Hours': 3,
#    'verbatim': ['a_0', 'b_1-4_Hours', 'c_5+_Hours']}),
#  ('q33_3',
#   {1: 'a_0',
#    2: 'b_1-4_Hours',
#    3: 'c_5+_Hours',
#    'a_0': 1,
#    'b_1-4_Hours': 2,
#    'c_5+_Hours': 3,
#    'verbatim': ['a_0', 'b_1-4_Hours', 'c_5+_Hours']}),
#  ('q33_2',
#   {1: 'a_0',
#    2: 'b_1-4_Hours',
#    3: 'c_5+_Hours',
#    'a_0': 1,
#    'b_1-4_Hours': 2,
#    'c_5+_Hours': 3,
#    'verbatim': ['a_0', 'b_1-4_Hours', 'c_5+_Hours']}),
#  ('q33_1',
#   {1: 'a_0',
#    2: 'b_1-4_Hours',
#    3: 'c_5+_Hours',
#    'a_0': 1,
#    'b_1-4_Hours': 2,
#    'c_5+_Hours': 3,
#    'verbatim': ['a_0', 'b_1-4_Hours', 'c_5+_Hours']}),
#  ('q35_5',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q35_4',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q35_7',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q35_6',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q35_1',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q35_3',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q35_2',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q35_9',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q35_8',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q52_1',
#   {1: 'a_None',
#    2: 'b_1_child',
#    3: 'c_2_children',
#    4: 'd_3_or_more_children',
#    5: 'n/a',
#    'a_None': 1,
#    'b_1_child': 2,
#    'c_2_children': 3,
#    'd_3_or_more_children': 4,
#    'n/a': 5,
#    'verbatim': ['a_None',
#     'b_1_child',
#     'c_2_children',
#     'd_3_or_more_children',
#     'n/a']}),
#  ('q52_2',
#   {1: 'a_None',
#    2: 'b_1_child',
#    3: 'c_2_children',
#    4: 'd_3_or_more_children',
#    5: 'n/a',
#    'a_None': 1,
#    'b_1_child': 2,
#    'c_2_children': 3,
#    'd_3_or_more_children': 4,
#    'n/a': 5,
#    'verbatim': ['a_None',
#     'b_1_child',
#     'c_2_children',
#     'd_3_or_more_children',
#     'n/a']}),
#  ('q52_3',
#   {1: 'a_None',
#    2: 'b_1_child',
#    3: 'c_2_children',
#    4: 'd_3_or_more_children',
#    5: 'n/a',
#    'a_None': 1,
#    'b_1_child': 2,
#    'c_2_children': 3,
#    'd_3_or_more_children': 4,
#    'n/a': 5,
#    'verbatim': ['a_None',
#     'b_1_child',
#     'c_2_children',
#     'd_3_or_more_children',
#     'n/a']}),
#  ('q48_19',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('Run 121 Seg',
#   {1: 'Active_TV',
#    2: 'Curious_Escapists',
#    3: 'Disagree',
#    4: 'Disagree2',
# ...
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q35_12',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q31_1',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q29_11', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q29_12', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q29_13', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q29_14', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q29_15', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q29_16', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q29_17', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q31_9',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q31_8',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q26_11',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q26_10',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q26_13',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q26_12',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q24a_9',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q24a_8',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q24a_7',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q24a_6',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q24a_5',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q24a_4',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q24a_3',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q24a_2',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q24a_1',
#   {1: '0',
#    2: '1',
#    3: 'n/a',
#    '0': 1,
#    '1': 2,
#    'n/a': 3,
#    'verbatim': ['0', '1', 'n/a']}),
#  ('q38_1', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_2', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_3', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_4', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_5', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_6', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_7', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_8', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_9', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('s09_10',
#   {1: 'a_Unlikely_1',
#    2: 'b_2',
#    3: 'c_3',
#    4: 'd_Somewhat_Likely_4',
#    5: 'e_5',
#    6: 'f_6',
#    7: 'g_Very_Likely_7',
#    8: 'n/a',
#    'a_Unlikely_1': 1,
#    'b_2': 2,
#    'c_3': 3,
#    'd_Somewhat_Likely_4': 4,
#    'e_5': 5,
#    'f_6': 6,
#    'g_Very_Likely_7': 7,
#    'n/a': 8,
#    'verbatim': ['a_Unlikely_1',
#     'b_2',
#     'c_3',
#     'd_Somewhat_Likely_4',
#     'e_5',
#     'f_6',
#     'g_Very_Likely_7',
#     'n/a']}),
#  ('s08_10',
#   {1: 'a_Unlikely_1',
#    2: 'b_2',
#    3: 'c_3',
#    4: 'd_Somewhat_Likely_4',
#    5: 'e_5',
#    6: 'f_6',
#    7: 'g_Very_Likely_7',
#    8: 'n/a',
#    'a_Unlikely_1': 1,
#    'b_2': 2,
#    'c_3': 3,
#    'd_Somewhat_Likely_4': 4,
#    'e_5': 5,
#    'f_6': 6,
#    'g_Very_Likely_7': 7,
#    'n/a': 8,
#    'verbatim': ['a_Unlikely_1',
#     'b_2',
#     'c_3',
#     'd_Somewhat_Likely_4',
#     'e_5',
#     'f_6',
#     'g_Very_Likely_7',
#     'n/a']}),
#  ('q07_18',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q07_19',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q07_14',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q07_15',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q07_16',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q07_17',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q07_10',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q07_11',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q07_12',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q07_13',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('s15',
#   {1: 'a_Less_than_$100',
#    2: 'b_$100-$249',
#    3: 'c_$250-$499',
#    4: 'd_$500-$1,999',
#    5: 'e_$2,000-$2,499',
#    6: 'f_$2,500_or_more',
#    7: 'z_I_do_not_know',
#    'a_Less_than_$100': 1,
#    'b_$100-$249': 2,
#    'c_$250-$499': 3,
#    'd_$500-$1,999': 4,
#    'e_$2,000-$2,499': 5,
#    'f_$2,500_or_more': 6,
#    'verbatim': ['a_Less_than_$100',
#     'b_$100-$249',
#     'c_$250-$499',
#     'd_$500-$1,999',
#     'e_$2,000-$2,499',
#     'f_$2,500_or_more',
#     'z_I_do_not_know'],
#    'z_I_do_not_know': 7}),
#  ('q38_18', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_12', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_13', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_10', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_11', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_16', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_17', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_14', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q38_15', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_10', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_11', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_12', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q03_13', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q48_18',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_28',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_29',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_20',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_21',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_22',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_23',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q48_24',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_25',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_26',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q48_27',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q31_19',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q31_18',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q31_11',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q31_10',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q31_13',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q31_12',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q31_15',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q31_14',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q31_17',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q31_16',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q41_99', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q20_6',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q20_5',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q20_4',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q20_3',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q20_2',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('q20_1',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q26_5',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q26_4',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q26_7',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q26_6',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q26_1',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q26_3',
#   {1: 'a_T3_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T3_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T3_Agree', 'b_M2_Neutral', 'c_B2_Disagree']}),
#  ('q26_2',
#   {1: 'a_T2_Agree',
#    2: 'b_M3_Neutral',
#    3: 'c_B2_Disagree',
#    'a_T2_Agree': 1,
#    'b_M3_Neutral': 2,
#    'c_B2_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M3_Neutral', 'c_B2_Disagree']}),
#  ('s07x1_11', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('s07x1_10', {1: '0', 2: '1', '0': 1, '1': 2, 'verbatim': ['0', '1']}),
#  ('q26_9',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']}),
#  ('q26_8',
#   {1: 'a_T2_Agree',
#    2: 'b_M2_Neutral',
#    3: 'c_B3_Disagree',
#    'a_T2_Agree': 1,
#    'b_M2_Neutral': 2,
#    'c_B3_Disagree': 3,
#    'verbatim': ['a_T2_Agree', 'b_M2_Neutral', 'c_B3_Disagree']})]

# %%
len(Y.ix[0,:])
# Out:
# 357
